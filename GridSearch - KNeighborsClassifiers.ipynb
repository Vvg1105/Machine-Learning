# %%
import pandas as pd

# %%
df = pd.read_csv('adult.data',header=None,names=["Age", "Workclass", "fnlwgt", "Education", "Education num", "Marital Status", "Occupation","Relationship", "Race", "Sex", "Capital gain","Capital loss", "Hours per week", "Native country","Income level"])

# %%
df
# Out:
#        Age          Workclass  fnlwgt    Education  Education num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
arr_no_cat=[]

# %%
for pos in df.columns:
    if(df[pos].dtypes=='int64'):
        arr_no_cat.append(pos)

# %%
print(arr_no_cat)
# Out:
# ['Age', 'fnlwgt', 'Education num', 'Capital gain', 'Capital loss', 'Hours per week']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder_y = LabelEncoder()

# %%
label = label_encoder_y.fit_transform(df[df.columns[-1]])

# %%
label
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.model_selection import GridSearchCV

# %%
arr_params = []
for num in range(29,100):
    arr_params.append(num)

# %%
paramters = {
    'n_neighbors': arr_params
}

# %%
model = KNeighborsClassifier()

# %%
grid_search = GridSearchCV(model,paramters)

# %%
df_no_cat = pd.DataFrame(data=[],columns=arr_no_cat)

# %%
for pos in df_no_cat.columns:
    df_no_cat[pos] = df[pos]

# %%
df_no_cat
# Out:
#        Age  fnlwgt  Education num  Capital gain  Capital loss  Hours per week
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# [32561 rows x 6 columns]

# %%
grid_GBR = grid_search.fit(df_no_cat,label)

# %%
print("The best score across ALL searched params:\n",grid_GBR.best_score_)
# Out:
# The best score across ALL searched params:
#  0.7988084169970399

# %%
print("The best parameters across ALL searched params:\n",grid_GBR.best_params_)
# Out:
# The best parameters across ALL searched params:
#  {'n_neighbors': 31}

# %%
df_grid = pd.DataFrame(data = grid_GBR.cv_results_)

# %%
df_grid
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.062069      0.004636         0.127514        0.000892
# 1        0.058937      0.000888         0.126784        0.000602
# 2        0.059056      0.000889         0.126671        0.000500
# 3        0.060450      0.002532         0.130970        0.004510
# 4        0.063189      0.001244         0.139076        0.006180
# ..            ...           ...              ...             ...
# 66       0.059952      0.001124         0.172825        0.000901
# 67       0.062646      0.002234         0.185344        0.002986
# 68       0.060915      0.001637         0.176649        0.002837
# 69       0.061608      0.001331         0.182138        0.003383
# 70       0.061986      0.003277         0.178516        0.003761
#
#    param_n_neighbors               params  split0_test_score  \
# 0                 29  {'n_neighbors': 29}           0.798096
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
data = scaler.fit_transform(df_no_cat)

# %%
df_n = pd.DataFrame(data,columns = arr_no_cat)

# %%
df_no_cat
# Out:
#        Age  fnlwgt  Education num  Capital gain  Capital loss  Hours per week
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# [32561 rows x 6 columns]

# %%
df_n
# Out:
#             Age    fnlwgt  Education num  Capital gain  Capital loss  \
# 0      0.030671 -1.063611       1.134739      0.148453      -0.21666
# 1      0.837109 -1.008707       1.134739     -0.145920      -0.21666
# 2     -0.042642  0.245079      -0.420060     -0.145920      -0.21666
# 3      1.057047  0.425801      -1.197459     -0.145920      -0.21666
# 4     -0.775768  1.408176       1.134739     -0.145920      -0.21666
# ...         ...       ...            ...           ...           ...
# 32556 -0.849080  0.639741       0.746039     -0.145920      -0.21666
# 32557  0.103983 -0.335433      -0.420060     -0.145920      -0.21666
# 32558  1.423610 -0.358777      -0.420060     -0.145920      -0.21666
# 32559 -1.215643  0.110960      -0.420060     -0.145920      -0.21666
# 32560  0.983734  0.929893      -0.420060      1.888424      -0.21666
#
#        Hours per week
# 0           -0.035429
# 1           -2.222153
# 2           -0.035429
# 3           -0.035429
# ...

# %%
df_no_cat
# Out:
#        Age  fnlwgt  Education num  Capital gain  Capital loss  Hours per week
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# [32561 rows x 6 columns]

# %%
u = df_no_cat['Age'].mean()

# %%
s = df_no_cat['Age'].std()

# %%
x = 39

# %%
print((x-u)/s)
# Out:
# 0.03067008638002341

# %%
model_scale = KNeighborsClassifier()

# %%
grid_search_scale = GridSearchCV(model_scale,paramters)

# %%
grid_GBR_scale = grid_search_scale.fit(df_n,label)

# %%
print("The best score across ALL searched params:\n",grid_GBR_scale.best_score_)
# Out:
# The best score across ALL searched params:
#  0.8223642725888235

# %%
print("The best parameters across ALL searched params:\n",grid_GBR_scale.best_params_)
# Out:
# The best parameters across ALL searched params:
#  {'n_neighbors': 44}

# %%
model_scale_dist = KNeighborsClassifier(metric = 'euclidean')

# %%
grid_search_scale_dist = GridSearchCV(model_scale_dist,paramters)

# %%
grid_GBR_scale_dist = grid_search_scale_dist.fit(df_n,label)

# %%
print("The best score across ALL searched params:\n",grid_GBR_scale_dist.best_score_)
# Out:
# The best score across ALL searched params:
#  0.8223642725888235

# %%
print("The best parameters across ALL searched params:\n",grid_GBR_scale_dist.best_params_)
# Out:
# The best parameters across ALL searched params:
#  {'n_neighbors': 44}

# %%
model_scale_dist_m = KNeighborsClassifier(metric = 'manhattan')

# %%
grid_search_scale_dist_m = GridSearchCV(model_scale_dist_m,paramters)

# %%
grid_GBR_scale_dist_m = grid_search_scale_dist_m.fit(df_n,label)

# %%
print("The best score across ALL searched params:\n",grid_GBR_scale_dist_m.best_score_)
# Out:
# The best score across ALL searched params:
#  0.8234392064481885

# %%
print("The best parameters across ALL searched params:\n",grid_GBR_scale_dist_m.best_params_)
# Out:
# The best parameters across ALL searched params:
#  {'n_neighbors': 77}
