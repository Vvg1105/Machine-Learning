# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv('adult.data',header=None,names=["Age", "Workclass", "fnlwgt", "Education", "Education num", "Marital Status", "Occupation","Relationship", "Race", "Sex", "Capital gain","Capital loss", "Hours per week", "Native country","Income level"])
df
# Out:
#        Age          Workclass  fnlwgt    Education  Education num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
from sklearn.model_selection import KFold

# %%
arr_cols = df.columns[:len(df.columns)-1]
arr_cols_prop=[]
for pos in arr_cols:
    objin = False
    if(df[pos].dtypes!='int64'):
        arr_cols_prop.append(pos)
print(arr_cols_prop)
X = df[arr_cols_prop]
X
# Out:
# ['Workclass', 'Education', 'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native country']
#                Workclass    Education       Marital Status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Native country
# ...

# %%
y_col = df.columns[-1]
y_col
# Out:
# 'Income level'

# %%
k = int(input("Type in randomness (i.e value k): "))
# Out:
# Type in randomness (i.e value k): 5

# %%
k
# Out:
# 5

# %%
kfold_validation = KFold(k)

# %%
y = df[y_col].to_frame()
y
# Out:
#       Income level
# 0            <=50K
# 1            <=50K
# 2            <=50K
# 3            <=50K
# 4            <=50K
# ...            ...
# 32556        <=50K
# 32557         >50K
# 32558        <=50K
# 32559        <=50K
# 32560         >50K
#
# [32561 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder_y = LabelEncoder()

# %%
data = []
label = pd.DataFrame(data, columns=[y_col+' Encode'])
label
# Out:
# Empty DataFrame
# Columns: [Income level Encode]
# Index: []

# %%
label[y_col+' Encode'] = label_encoder_y.fit_transform(y[y_col])
label
# Out:
#        Income level Encode
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 32556                    0
# 32557                    1
# 32558                    0
# 32559                    0
# 32560                    1
#
# [32561 rows x 1 columns]

# %%
arr_cols_encode = []
for pos in range(0,len(arr_cols_prop)):
    arr_cols_encode.append(arr_cols_prop[pos]+' Encode')

# %%
X_copy = X
X_copy
# Out:
#                Workclass    Education       Marital Status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Native country
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
label_object = {}
for col in arr_cols_prop:
    labelencoder = LabelEncoder()
    labelencoder.fit(X[col])
    X_copy[col+' Encode'] = labelencoder.fit_transform(X_copy[col])
    label_object[col] = labelencoder
print(label_object)
# Out:
# {'Workclass': LabelEncoder(), 'Education': LabelEncoder(), 'Marital Status': LabelEncoder(), 'Occupation': LabelEncoder(), 'Relationship': LabelEncoder(), 'Race': LabelEncoder(), 'Sex': LabelEncoder(), 'Native country': LabelEncoder()}
# <ipython-input-16-f03f9a06056b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_copy[col+' Encode'] = labelencoder.fit_transform(X_copy[col])

# %%
X_copy
# Out:
#                Workclass    Education       Marital Status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Native country  \
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
X_copy = X_copy.drop(arr_cols_prop, axis=1)

# %%
label_arr = label[y_col+' Encode']
print(label_arr)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: Income level Encode, Length: 32561, dtype: int64

# %%
from sklearn.naive_bayes import CategoricalNB

# %%
model = CategoricalNB()

# %%
from sklearn.model_selection import cross_val_score

# %%
results = cross_val_score(model,X_copy,label,cv=k)
# Out:
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
print(results)
# Out:
# [0.79579303 0.79284398 0.79176904 0.79944717 0.7919226 ]

# %%
import numpy as np

# %%
print('Accuracy after cross validation is:',str(np.mean(results)*100)+'%')
# Out:
# Accuracy after cross validation is: 79.4355166061753%
