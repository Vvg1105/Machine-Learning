# %%
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
df = pd.read_csv('adult.data',header=None,names=["Age", "Workclass", "fnlwgt", "Education", "Education num", "Marital Status", "Occupation","Relationship", "Race", "Sex", "Capital gain","Capital loss", "Hours per week", "Native country","Income level"])
df
# Out:
#        Age          Workclass  fnlwgt    Education  Education num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
arr_cols = df.columns[:len(df.columns)-1]
col=[]
for pos in arr_cols:
    objin = False
    if(df[pos].dtypes!='int64'):
        col.append(pos)
print(col)
X = df[col]
X
# Out:
# ['Workclass', 'Education', 'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native country']
#                Workclass    Education       Marital Status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Native country
# ...

# %% [markdown]
# df[col] allows you to show all the data within those columns.

# %%
y=df[df.columns[len(df.columns)-1]]
y.to_frame()
# Out:
#       Income level
# 0            <=50K
# 1            <=50K
# 2            <=50K
# 3            <=50K
# 4            <=50K
# ...            ...
# 32556        <=50K
# 32557         >50K
# 32558        <=50K
# 32559        <=50K
# 32560         >50K
#
# [32561 rows x 1 columns]

# %%
col_name = df.columns[len(df.columns)-1]
print(col_name)
# Out:
# Income level

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
y_train = y_train.to_frame()
y_test = y_test.to_frame()

# %% [markdown]
# Instead of randomly appending rows into a list and finding those corresponding values, you can just do the above, the X and the y need to be in a Dataframe format and test_size is the parameter which in this case splits the data randomly into chunks of 70% of data and 30% of data.

# %%
X_train
# Out:
#            Workclass      Education       Marital Status          Occupation  \
# 11138   Self-emp-inc      Bachelors   Married-civ-spouse     Exec-managerial
# 22186        Private        HS-grad   Married-civ-spouse        Craft-repair
# 31252        Private   Some-college   Married-civ-spouse     Exec-managerial
# 24988        Private     Assoc-acdm   Married-civ-spouse        Tech-support
# 31684    Federal-gov   Some-college   Married-civ-spouse      Prof-specialty
# ...              ...            ...                  ...                 ...
# 27669        Private           11th        Never-married   Handlers-cleaners
# 11631        Private   Some-college        Never-married        Tech-support
# 26410              ?            9th        Never-married                   ?
# 2957       Local-gov        Masters            Separated      Prof-specialty
# 18896        Private        HS-grad             Divorced     Exec-managerial
#
# ...

# %%
import numpy as np

# %%
X_train['Rows'] = np.arange(len(X_train))
# Out:
# <ipython-input-11-1152be507773>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Rows'] = np.arange(len(X_train))

# %%
X_train = X_train.groupby('Rows').first()

# %%
X_train
# Out:
#            Workclass      Education       Marital Status          Occupation  \
# Rows
# 0       Self-emp-inc      Bachelors   Married-civ-spouse     Exec-managerial
# 1            Private        HS-grad   Married-civ-spouse        Craft-repair
# 2            Private   Some-college   Married-civ-spouse     Exec-managerial
# 3            Private     Assoc-acdm   Married-civ-spouse        Tech-support
# 4        Federal-gov   Some-college   Married-civ-spouse      Prof-specialty
# ...              ...            ...                  ...                 ...
# 22787        Private           11th        Never-married   Handlers-cleaners
# 22788        Private   Some-college        Never-married        Tech-support
# 22789              ?            9th        Never-married                   ?
# 22790      Local-gov        Masters            Separated      Prof-specialty
# 22791        Private        HS-grad             Divorced     Exec-managerial
#
# ...

# %%
y_train
# Out:
#       Income level
# 11138        <=50K
# 22186        <=50K
# 31252         >50K
# 24988        <=50K
# 31684         >50K
# ...            ...
# 27669        <=50K
# 11631        <=50K
# 26410        <=50K
# 2957         <=50K
# 18896        <=50K
#
# [22792 rows x 1 columns]

# %%
y_train['Rows'] = np.arange(len(y_train))

# %%
y_train = y_train.groupby('Rows').first()

# %%
y_train
# Out:
#       Income level
# Rows
# 0            <=50K
# 1            <=50K
# 2             >50K
# 3            <=50K
# 4             >50K
# ...            ...
# 22787        <=50K
# 22788        <=50K
# 22789        <=50K
# 22790        <=50K
# 22791        <=50K
#
# [22792 rows x 1 columns]

# %%
X_test
# Out:
#                Workclass      Education       Marital Status  \
# 31027            Private        HS-grad        Never-married
# 25394            Private     Assoc-acdm        Never-married
# 28032            Private   Some-college        Never-married
# 28095            Private        HS-grad             Divorced
# 16511   Self-emp-not-inc        HS-grad   Married-civ-spouse
# ...                  ...            ...                  ...
# 1571             Private     Assoc-acdm   Married-civ-spouse
# 26495            Private        HS-grad   Married-civ-spouse
# 594              Private      Bachelors        Never-married
# 15047            Private        HS-grad        Never-married
# 12790        Federal-gov     Assoc-acdm   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Native country
# 31027    Transport-moving       Own-child   White     Male   United-States
# 25394        Tech-support   Not-in-family   Black     Male         England
# ...

# %%
X_test['Rows'] = np.arange(len(X_test))
X_test = X_test.groupby('Rows').first()
X_test
# Out:
# <ipython-input-19-80481bcefc5f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Rows'] = np.arange(len(X_test))
#               Workclass      Education       Marital Status  \
# Rows
# 0               Private        HS-grad        Never-married
# 1               Private     Assoc-acdm        Never-married
# 2               Private   Some-college        Never-married
# 3               Private        HS-grad             Divorced
# 4      Self-emp-not-inc        HS-grad   Married-civ-spouse
# ...                 ...            ...                  ...
# 9764            Private     Assoc-acdm   Married-civ-spouse
# 9765            Private        HS-grad   Married-civ-spouse
# ...

# %%
y_test
# Out:
#       Income level
# 31027        <=50K
# 25394         >50K
# 28032        <=50K
# 28095        <=50K
# 16511        <=50K
# ...            ...
# 1571          >50K
# 26495         >50K
# 594          <=50K
# 15047        <=50K
# 12790         >50K
#
# [9769 rows x 1 columns]

# %%
y_test['Rows'] = np.arange(len(y_test))
y_test = y_test.groupby('Rows').first()
y_test
# Out:
#      Income level
# Rows
# 0           <=50K
# 1            >50K
# 2           <=50K
# 3           <=50K
# 4           <=50K
# ...           ...
# 9764         >50K
# 9765         >50K
# 9766        <=50K
# 9767        <=50K
# 9768         >50K
#
# [9769 rows x 1 columns]

# %%
arr_s1=[]
for pos in range (0,y_train.shape[0]):
    arr_s1.append(y_train[col_name][pos])
arr_s = set(arr_s1)
print(arr_s)
# Out:
# {' <=50K', ' >50K'}

# %%
print(y_train['Income level'][0])
# Out:
#  <=50K

# %%
print(y_train.at[0,'Income level'])
# Out:
#  <=50K

# %%
#Naive Bayes Train Test Homework

# %%
no_mult= {
    
}

# %%
for pos in X:
    arr_dict=[]
    no_mult[pos]={}
    arr_se=[]
    for row in range(0,X_train.shape[0]):
        arr_se.append(X_train[pos][row])
    arr_set = set(arr_se)
    iterator = iter(arr_set)
    for copy in range(0,len(arr_set)):
        a = next(iterator, None)
        arr_dict.append(a)
    no_mult[pos]=arr_dict
print(no_mult)
# Out:
# {'Workclass': [' Self-emp-inc', ' Local-gov', ' Private', ' Self-emp-not-inc', ' Federal-gov', ' Without-pay', ' State-gov', ' Never-worked', ' ?'], 'Education': [' Masters', ' 7th-8th', ' 1st-4th', ' 10th', ' Prof-school', ' Assoc-voc', ' 12th', ' HS-grad', ' Some-college', ' Bachelors', ' Doctorate', ' 11th', ' 9th', ' 5th-6th', ' Assoc-acdm', ' Preschool'], 'Marital Status': [' Divorced', ' Separated', ' Married-spouse-absent', ' Never-married', ' Married-civ-spouse', ' Widowed', ' Married-AF-spouse'], 'Occupation': [' Farming-fishing', ' Exec-managerial', ' Transport-moving', ' Other-service', ' Machine-op-inspct', ' Armed-Forces', ' Handlers-cleaners', ' Craft-repair', ' Protective-serv', ' Priv-house-serv', ' ?', ' Prof-specialty', ' Tech-support', ' Adm-clerical', ' Sales'], 'Relationship': [' Other-relative', ' Husband', ' Unmarried', ' Not-in-family', ' Wife', ' Own-child'], 'Race': [' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other', ' White'], 'Sex': [' Femal
# ...

# %%
freq=[]
count1=0
for pos in arr_s:
    count1=0
    for row in range(0,y_train.shape[0]):
        if(y_train['Income level'][row]==pos):
            count1+=1
    freq.append(count1)
print(freq)
# Out:
# [17304, 5488]

# %%
iterator = iter(arr_s)
diction={
}
for pos in range(0,len(arr_s)):
    a = next(iterator, None)
    diction[a]=freq[pos]
print(diction)
# Out:
# {' <=50K': 17304, ' >50K': 5488}

# %%
arr_cols = X_train.columns[:len(X_train.columns)]
arr_cols_prop=[]
for pos in arr_cols:
    objin = False
    if(X_train[pos].dtypes!='int64'):
        arr_cols_prop.append(pos)
print(arr_cols_prop)
# Out:
# ['Workclass', 'Education', 'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native country']

# %%
prop_dict={
    
}

# %%
print(X_train.at[0,'Education'])
# Out:
#  Bachelors

# %%
output = y_train.columns[-1]
print(output)
# Out:
# Income level

# %%
for pos in arr_cols_prop:
    prop_dict[pos]={}
    for copy in arr_s:
        for val in range(0,len(no_mult[pos])):
            frequency=0
            freq_total=0
            value = no_mult[pos][val]
            for row in range(0, X_train.shape[0]):
                if(X_train.at[row,pos]==value and y_train.at[row,output]==copy):
                    frequency+=1
                if(y_train.at[row,output]==copy):
                    freq_total+=1
            prop_dict[pos][value+copy]=frequency/freq_total
print(prop_dict)
# Out:
# {'Workclass': {' Self-emp-inc <=50K': 0.020399907535829865, ' Local-gov <=50K': 0.05883032824780397, ' Private <=50K': 0.7160194174757282, ' Self-emp-not-inc <=50K': 0.07564724919093851, ' Federal-gov <=50K': 0.023982894128525195, ' Without-pay <=50K': 0.0006356911696717522, ' State-gov <=50K': 0.037736939435968564, ' Never-worked <=50K': 0.00028895053166897827, ' ? <=50K': 0.066458622283865, ' Self-emp-inc >50K': 0.07817055393586006, ' Local-gov >50K': 0.07908163265306123, ' Private >50K': 0.6293731778425656, ' Self-emp-not-inc >50K': 0.09511661807580175, ' Federal-gov >50K': 0.048104956268221574, ' Without-pay >50K': 0.0, ' State-gov >50K': 0.04628279883381924, ' Never-worked >50K': 0.0, ' ? >50K': 0.023870262390670555}, 'Education': {' Masters <=50K': 0.030224225612575126, ' 7th-8th <=50K': 0.024849745723532133, ' 1st-4th <=50K': 0.006877022653721683, ' 10th <=50K': 0.03507859454461396, ' Prof-school <=50K': 0.006067961165048544, ' Assoc-voc <=50K': 0.04079981507165973, ' 12th <=5
# ...

# %%
denom = len(X_test)
print(denom)
# Out:
# 9769

# %%
dict_vals={

}

# %%
for copy in arr_s:
    freq_copy=0
    for row in range(0,X_test.shape[0]):
        if(y_test.at[row,output]==copy):
            freq_copy+=1
    ans = freq_copy/denom
    dict_vals[copy] = ans
print(dict_vals)
# Out:
# {' <=50K': 0.7591360425836831, ' >50K': 0.24086395741631692}

# %%
new_dict={
}

# %%
pred = {
    
}

# %%
for row in range(0,X_test.shape[0]):
    arr_results=[]
    for copy in arr_s:
        total=1
        total1=1
        incre = False
        for pos in arr_cols_prop:
            if(incre==False):
                total*=prop_dict[pos][X_test.at[row,pos]+copy]
            else:
                total1*=prop_dict[pos][X_test.at[row,pos]+copy]
            incre=True
        total*=dict_vals[copy]
        total1*=dict_vals[copy]
        new_dict['Row'+str(row)+copy]=total
        new_dict['Row'+str(row)+copy]=total1
        if(total1>total):
            pred['Row'+str(row)+copy] = total1
        else:
            pred['Row'+str(row)+copy] = total
print(new_dict)
# Out:
# {'Row0 <=50K': 0.0005457880377200773, 'Row0 >50K': 7.756845657633502e-07, 'Row1 <=50K': 1.3904388477979067e-08, 'Row1 >50K': 2.827812865438219e-10, 'Row2 <=50K': 0.0005379005917016705, 'Row2 >50K': 1.9710231964442333e-06, 'Row3 <=50K': 0.00018161694029851874, 'Row3 >50K': 1.303368013729275e-06, 'Row4 <=50K': 0.0015678252328586158, 'Row4 >50K': 0.0028048790293759506, 'Row5 <=50K': 0.00019379040250832918, 'Row5 >50K': 0.00010025950573088502, 'Row6 <=50K': 0.00045207604733070504, 'Row6 >50K': 3.6370645491574693e-06, 'Row7 <=50K': 8.626471709030643e-05, 'Row7 >50K': 0.003325604244380416, 'Row8 <=50K': 2.6149793731766125e-05, 'Row8 >50K': 2.9595020116206367e-08, 'Row9 <=50K': 0.0003702380857599595, 'Row9 >50K': 6.9063360540181155e-06, 'Row10 <=50K': 0.00032517717438123895, 'Row10 >50K': 9.497061776046702e-06, 'Row11 <=50K': 7.486873823924612e-05, 'Row11 >50K': 0.000852739905668471, 'Row12 <=50K': 0.0008456159350749062, 'Row12 >50K': 0.0008239598975183538, 'Row13 <=50K': 0.0001033597948428
# ...

# %%
prop_pred={
    
}

# %%
for row in range(0,X_test.shape[0]):
    arr_pred=[]
    tot_pred=0
    cop_pred=''
    for copy in arr_s:
        if(pred['Row'+str(row)+copy]>tot_pred):
            tot_pred = pred['Row'+str(row)+copy]
            cop_pred=copy
    prop_pred['Row'+str(row)]=cop_pred
print(prop_pred)
# Out:
# {'Row0': ' <=50K', 'Row1': ' <=50K', 'Row2': ' <=50K', 'Row3': ' <=50K', 'Row4': ' <=50K', 'Row5': ' <=50K', 'Row6': ' <=50K', 'Row7': ' <=50K', 'Row8': ' <=50K', 'Row9': ' <=50K', 'Row10': ' <=50K', 'Row11': ' <=50K', 'Row12': ' <=50K', 'Row13': ' <=50K', 'Row14': ' <=50K', 'Row15': ' <=50K', 'Row16': ' <=50K', 'Row17': ' <=50K', 'Row18': ' <=50K', 'Row19': ' <=50K', 'Row20': ' <=50K', 'Row21': ' <=50K', 'Row22': ' <=50K', 'Row23': ' <=50K', 'Row24': ' <=50K', 'Row25': ' <=50K', 'Row26': ' <=50K', 'Row27': ' <=50K', 'Row28': ' >50K', 'Row29': ' <=50K', 'Row30': ' <=50K', 'Row31': ' <=50K', 'Row32': ' <=50K', 'Row33': ' <=50K', 'Row34': ' <=50K', 'Row35': ' <=50K', 'Row36': ' <=50K', 'Row37': ' <=50K', 'Row38': ' <=50K', 'Row39': ' <=50K', 'Row40': ' <=50K', 'Row41': ' <=50K', 'Row42': ' <=50K', 'Row43': ' <=50K', 'Row44': ' <=50K', 'Row45': ' <=50K', 'Row46': ' <=50K', 'Row47': ' <=50K', 'Row48': ' <=50K', 'Row49': ' <=50K', 'Row50': ' >50K', 'Row51': ' <=50K', 'Row52': ' <=50K', 'R
# ...

# %%
print(len(prop_pred))
# Out:
# 9769

# %%
acc=0
for row in range(0,y_test.shape[0]):
    if(y_test.at[row,output]==prop_pred['Row'+str(row)]):
        acc+=1
print(acc/len(prop_pred))
# Out:
# 0.764459002968574

# %%
print('Accuracy is: ',(acc/len(prop_pred))*100,"%")
# Out:
# Accuracy is:  76.4459002968574 %

# %%
from sklearn.preprocessing import LabelEncoder

# %%
bridge_types = ('Arch','Beam','Truss','Cantilever','Tied Arch','Suspension','Cable')
bridge_df = pd.DataFrame(bridge_types, columns=['Bridge Types'])

# %%
bridge_df
# Out:
#   Bridge Types
# 0         Arch
# 1         Beam
# 2        Truss
# 3   Cantilever
# 4    Tied Arch
# 5   Suspension
# 6        Cable

# %% [markdown]
# Creating Instance of Labelencoder

# %%
labelencoder = LabelEncoder()

# %%
bridge_df['Bridge_Types_Cat'] = labelencoder.fit_transform(bridge_df['Bridge Types'])
bridge_df
# Out:
#   Bridge Types  Bridge_Types_Cat
# 0         Arch                 0
# 1         Beam                 1
# 2        Truss                 6
# 3   Cantilever                 3
# 4    Tied Arch                 5
# 5   Suspension                 4
# 6        Cable                 2

# %%
df
# Out:
#        Age          Workclass  fnlwgt    Education  Education num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
print(arr_cols_prop)
# Out:
# ['Workclass', 'Education', 'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native country']

# %%
index_cols = []

# %%
for pos in arr_cols_prop:
    index_no = df.columns.get_loc(pos)
    index_cols.append(index_no)
print(index_cols)
# Out:
# [1, 3, 5, 6, 7, 8, 9, 13]

# %%
labelencoder = LabelEncoder()

# %%
count=0
for num in range(0,len(index_cols)):
    df.insert(loc=index_cols[num]+1+count, column=arr_cols_prop[num]+' Encode', value= labelencoder.fit_transform(df[arr_cols_prop[num]]))
    count+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-78335c920eec> in <module>
#       1 count=0
#       2 for num in range(0,len(index_cols)):
# ----> 3     df.insert(loc=index_cols[num]+1+count, column=arr_cols_prop[num]+' Encode', value= labelencoder.fit_transform(df[arr_cols_prop[num]]))
#       4     count+=1
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
# ...

# %%
df
# Out:
#        Age          Workclass  Workclass Encode  fnlwgt    Education  \
# 0       39          State-gov                 7   77516    Bachelors
# 1       50   Self-emp-not-inc                 6   83311    Bachelors
# 2       38            Private                 4  215646      HS-grad
# 3       53            Private                 4  234721         11th
# 4       28            Private                 4  338409    Bachelors
# ...    ...                ...               ...     ...          ...
# 32556   27            Private                 4  257302   Assoc-acdm
# 32557   40            Private                 4  154374      HS-grad
# 32558   58            Private                 4  151910      HS-grad
# 32559   22            Private                 4  201490      HS-grad
# 32560   52       Self-emp-inc                 5  287927      HS-grad
#
#        Education Encode  Education num       Marital Status  \
# 0                     9             13        Never-married
# ...

# %%
diction_encode={
    
}
for pos in arr_cols_prop:
    diction_encode[pos] = {}
    arr_vals_n=[]
    arr_vals_c=[]
    arr_vals_num=[]
    arr_vals_cat=[]
    for row in range(0,df.shape[0]):
        arr_vals_c.append(df.at[row,pos])
        arr_vals_n.append(df.at[row,pos+' Encode'])
    arr_vals_num = set(arr_vals_n)
    arr_vals_cat = set(arr_vals_c)
    iter1 = iter(arr_vals_cat)
    iter2 = iter(arr_vals_num)
    for dat in range(0,len(arr_vals_cat)):
        a1 = next(iter1, None)
        a2 = next(iter2, None)
        diction_encode[pos][a2] = a1
print(diction_encode)
# Out:
# {'Workclass': {0: ' Self-emp-inc', 1: ' Local-gov', 2: ' Private', 3: ' Self-emp-not-inc', 4: ' Federal-gov', 5: ' Without-pay', 6: ' State-gov', 7: ' Never-worked', 8: ' ?'}, 'Education': {0: ' 7th-8th', 1: ' 1st-4th', 2: ' Assoc-voc', 3: ' Prof-school', 4: ' 10th', 5: ' Assoc-acdm', 6: ' 12th', 7: ' HS-grad', 8: ' Bachelors', 9: ' Some-college', 10: ' Doctorate', 11: ' 11th', 12: ' 9th', 13: ' 5th-6th', 14: ' Masters', 15: ' Preschool'}, 'Marital Status': {0: ' Divorced', 1: ' Separated', 2: ' Married-spouse-absent', 3: ' Never-married', 4: ' Married-civ-spouse', 5: ' Widowed', 6: ' Married-AF-spouse'}, 'Occupation': {0: ' Farming-fishing', 1: ' Exec-managerial', 2: ' Transport-moving', 3: ' Other-service', 4: ' Machine-op-inspct', 5: ' Armed-Forces', 6: ' Handlers-cleaners', 7: ' Craft-repair', 8: ' Protective-serv', 9: ' Priv-house-serv', 10: ' ?', 11: ' Prof-specialty', 12: ' Tech-support', 13: ' Adm-clerical', 14: ' Sales'}, 'Relationship': {0: ' Other-relative', 1: ' Husband',
# ...
