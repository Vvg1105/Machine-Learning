# %%
import pandas as pd

# %%
df = pd.read_csv('adult.data',header=None,names=["Age", "Workclass", "fnlwgt", "Education", "Education num", "Marital Status", "Occupation","Relationship", "Race", "Sex", "Capital gain","Capital loss", "Hours per week", "Native country","Income level"])

# %%
df
# Out:
#        Age          Workclass  fnlwgt    Education  Education num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital gain  Capital loss  Hours per week  Native country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#       Income level
# 0            <=50K
# 1            <=50K
# 2            <=50K
# 3            <=50K
# 4            <=50K
# ...            ...
# 32556        <=50K
# 32557         >50K
# 32558        <=50K
# 32559        <=50K
# 32560         >50K
#
# [32561 rows x 15 columns]

# %%
arr_cat = []

# %%
cols = df.columns[:-1]

# %%
cols
# Out:
# Index(['Age', 'Workclass', 'fnlwgt', 'Education', 'Education num',
#        'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital gain', 'Capital loss', 'Hours per week', 'Native country'],
#       dtype='object')

# %%
for pos in range(0,len(cols)):
    if(df[cols[pos]].dtype != 'int64'):
        arr_cat.append(cols[pos])

# %%
arr_cat
# Out:
# ['Workclass',
#  'Education',
#  'Marital Status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Native country']

# %%
arr_no_cat = []
for pos in df.columns:
    if(pos not in arr_cat and pos!=df.columns[-1]):
        arr_no_cat.append(pos)

# %%
arr_no_cat
# Out:
# ['Age',
#  'fnlwgt',
#  'Education num',
#  'Capital gain',
#  'Capital loss',
#  'Hours per week']

# %%
arr_encode=[]
for pos in arr_cat:
    arr_encode.append(pos+' Encode')
for pos in arr_no_cat:
    arr_encode.append(pos)

# %%
df_pipe = pd.DataFrame(data=[],columns=arr_encode)

# %%
df_pipe
# Out:
# Empty DataFrame
# Columns: [Workclass Encode, Education Encode, Marital Status Encode, Occupation Encode, Relationship Encode, Race Encode, Sex Encode, Native country Encode, Age, fnlwgt, Education num, Capital gain, Capital loss, Hours per week]
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder_y = LabelEncoder()

# %%
data_y = label_encoder_y.fit_transform(df[df.columns[-1]])

# %%
label_encoder_y
# Out:
# LabelEncoder()

# %%
label = pd.DataFrame(data=data_y, columns=[df.columns[-1]+' Encode'])

# %%
label
# Out:
#        Income level Encode
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 32556                    0
# 32557                    1
# 32558                    0
# 32559                    0
# 32560                    1
#
# [32561 rows x 1 columns]

# %%
df_pipe
# Out:
# Empty DataFrame
# Columns: [Workclass Encode, Education Encode, Marital Status Encode, Occupation Encode, Relationship Encode, Race Encode, Sex Encode, Native country Encode, Age, fnlwgt, Education num, Capital gain, Capital loss, Hours per week]
# Index: []

# %%
label_object = {}
for col in arr_cat:
    labelencoder = LabelEncoder()
    labelencoder.fit(df[col])
    df_pipe[col+' Encode'] = labelencoder.fit_transform(df[col])
    label_object[col] = labelencoder
print(label_object)
# Out:
# {'Workclass': LabelEncoder(), 'Education': LabelEncoder(), 'Marital Status': LabelEncoder(), 'Occupation': LabelEncoder(), 'Relationship': LabelEncoder(), 'Race': LabelEncoder(), 'Sex': LabelEncoder(), 'Native country': LabelEncoder()}

# %%
df
# Out:
#        Age          Workclass  fnlwgt    Education  Education num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital gain  Capital loss  Hours per week  Native country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#       Income level
# 0            <=50K
# 1            <=50K
# 2            <=50K
# 3            <=50K
# 4            <=50K
# ...            ...
# 32556        <=50K
# 32557         >50K
# 32558        <=50K
# 32559        <=50K
# 32560         >50K
#
# [32561 rows x 15 columns]

# %%
df_pipe
# Out:
#        Workclass Encode  Education Encode  Marital Status Encode  \
# 0                     7                 9                      4
# 1                     6                 9                      2
# 2                     4                11                      0
# 3                     4                 1                      2
# 4                     4                 9                      2
# ...                 ...               ...                    ...
# 32556                 4                 7                      2
# 32557                 4                11                      2
# 32558                 4                11                      6
# 32559                 4                11                      4
# 32560                 5                11                      2
#
#        Occupation Encode  Relationship Encode  Race Encode  Sex Encode  \
# 0                      1                    1            4           1
# 1                      4                    0            4           1
# 2                      6                    1            4           1
# 3                      6                    0            2           1
# 4                     10                    5            2           0
# ...                  ...                  ...          ...         ...
# 32556                 13                    5            4           0
# 32557                  7                    0            4           1
# 32558                  1                    4            4           0
# 32559                  1                    3            4           1
# 32560                  4                    5            4           0
#
#        Native country Encode  Age fnlwgt Education num Capital gain  \
# 0                         39  NaN    NaN           NaN          NaN
# 1                         39  NaN    NaN           NaN          NaN
# 2                         39  NaN    NaN           NaN          NaN
# 3                         39  NaN    NaN           NaN          NaN
# 4                          5  NaN    NaN           NaN          NaN
# ...                      ...  ...    ...           ...          ...
# 32556                     39  NaN    NaN           NaN          NaN
# 32557                     39  NaN    NaN           NaN          NaN
# 32558                     39  NaN    NaN           NaN          NaN
# 32559                     39  NaN    NaN           NaN          NaN
# 32560                     39  NaN    NaN           NaN          NaN
#
#       Capital loss Hours per week
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# ...            ...            ...
# 32556          NaN            NaN
# 32557          NaN            NaN
# 32558          NaN            NaN
# 32559          NaN            NaN
# 32560          NaN            NaN
#
# [32561 rows x 14 columns]

# %%
for col in arr_no_cat:
    df_pipe[col] = df[col]

# %%
df_pipe
# Out:
#        Workclass Encode  Education Encode  Marital Status Encode  \
# 0                     7                 9                      4
# 1                     6                 9                      2
# 2                     4                11                      0
# 3                     4                 1                      2
# 4                     4                 9                      2
# ...                 ...               ...                    ...
# 32556                 4                 7                      2
# 32557                 4                11                      2
# 32558                 4                11                      6
# 32559                 4                11                      4
# 32560                 5                11                      2
#
#        Occupation Encode  Relationship Encode  Race Encode  Sex Encode  \
# 0                      1                    1            4           1
# 1                      4                    0            4           1
# 2                      6                    1            4           1
# 3                      6                    0            2           1
# 4                     10                    5            2           0
# ...                  ...                  ...          ...         ...
# 32556                 13                    5            4           0
# 32557                  7                    0            4           1
# 32558                  1                    4            4           0
# 32559                  1                    3            4           1
# 32560                  4                    5            4           0
#
#        Native country Encode  Age  fnlwgt  Education num  Capital gain  \
# 0                         39   39   77516             13          2174
# 1                         39   50   83311             13             0
# 2                         39   38  215646              9             0
# 3                         39   53  234721              7             0
# 4                          5   28  338409             13             0
# ...                      ...  ...     ...            ...           ...
# 32556                     39   27  257302             12             0
# 32557                     39   40  154374              9             0
# 32558                     39   58  151910              9             0
# 32559                     39   22  201490              9             0
# 32560                     39   52  287927              9         15024
#
#        Capital loss  Hours per week
# 0                 0              40
# 1                 0              13
# 2                 0              40
# 3                 0              40
# 4                 0              40
# ...             ...             ...
# 32556             0              38
# 32557             0              40
# 32558             0              40
# 32559             0              20
# 32560             0              40
#
# [32561 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.pipeline import Pipeline

# %%
X_train,X_test,y_train,y_test = train_test_split(df_pipe, label, test_size=0.30)

# %%
X_train
# Out:
#        Workclass Encode  Education Encode  Marital Status Encode  \
# 2505                  6                11                      6
# 25703                 0                15                      4
# 17643                 0                 1                      0
# 29123                 4                15                      2
# 21493                 4                11                      2
# ...                 ...               ...                    ...
# 2758                  4                15                      5
# 2028                  1                15                      2
# 24128                 4                 9                      2
# 4070                  4                 1                      4
# 22998                 4                15                      4
#
#        Occupation Encode  Relationship Encode  Race Encode  Sex Encode  \
# 2505                   3                    1            4           1
# 25703                  0                    3            4           0
# 17643                  0                    1            4           0
# 29123                 11                    0            4           1
# 21493                  7                    0            4           1
# ...                  ...                  ...          ...         ...
# 2758                   4                    1            2           1
# 2028                  13                    0            4           1
# 24128                  4                    0            4           1
# 4070                   6                    3            4           1
# 22998                  4                    1            4           1
#
#        Native country Encode  Age  fnlwgt  Education num  Capital gain  \
# 2505                      39   57   73309              9             0
# 25703                     39   19  185619             10             0
# 17643                     39   20  238685              7             0
# 29123                     39   29  191722             10          7688
# 21493                     39   31  113838              9             0
# ...                      ...  ...     ...            ...           ...
# 2758                      39   40  225978             10             0
# 2028                      39   44  220563             10             0
# 24128                     39   45  242391             13             0
# 4070                      39   90  313986              7             0
# 22998                     39   41  116103             10             0
#
#        Capital loss  Hours per week
# 2505              0              55
# 25703             0              20
# 17643             0              40
# 29123             0              54
# 21493             0              45
# ...             ...             ...
# 2758              0              40
# 2028              0              40
# 24128             0              60
# 4070              0              40
# 22998             0              50
#
# [22792 rows x 14 columns]

# %%
X_test
# Out:
#        Workclass Encode  Education Encode  Marital Status Encode  \
# 6835                  2                12                      0
# 26457                 5                 9                      2
# 9167                  6                 8                      4
# 2814                  4                 9                      4
# 7659                  4                 9                      2
# ...                 ...               ...                    ...
# 28561                 4                12                      2
# 19588                 4                 1                      0
# 15900                 1                 9                      4
# 7133                  4                 5                      4
# 7317                  5                12                      2
#
#        Occupation Encode  Relationship Encode  Race Encode  Sex Encode  \
# 6835                  10                    4            4           0
# 26457                  4                    0            1           1
# 9167                   3                    1            4           1
# 2814                  12                    3            4           1
# 7659                  10                    0            3           1
# ...                  ...                  ...          ...         ...
# 28561                 10                    0            4           1
# 19588                  7                    4            4           0
# 15900                 10                    3            4           1
# 7133                   5                    4            4           1
# 7317                  12                    0            4           1
#
#        Native country Encode  Age  fnlwgt  Education num  Capital gain  \
# 6835                      39   39  178100             14             0
# 26457                     36   41   93227             13             0
# 9167                      39   32   97723             11             0
# 2814                      39   27  214858             13             0
# 7659                       7   32  227214             13             0
# ...                      ...  ...     ...            ...           ...
# 28561                      2   51   82578             14             0
# 19588                     39   27  246440              7             0
# 15900                     39   22  274103             13             0
# 7133                      39   21  346693              4             0
# 7317                      39   67  330144             14             0
#
#        Capital loss  Hours per week
# 6835              0              40
# 26457          1977              60
# 9167              0              40
# 2814              0              40
# 7659              0              40
# ...             ...             ...
# 28561             0              38
# 19588             0              40
# 15900             0              10
# 7133              0              40
# 7317              0              48
#
# [9769 rows x 14 columns]

# %%
y_train
# Out:
#        Income level Encode
# 2505                     1
# 25703                    0
# 17643                    0
# 29123                    1
# 21493                    0
# ...                    ...
# 2758                     0
# 2028                     0
# 24128                    1
# 4070                     0
# 22998                    0
#
# [22792 rows x 1 columns]

# %%
y_test
# Out:
#        Income level Encode
# 6835                     0
# 26457                    1
# 9167                     0
# 2814                     0
# 7659                     0
# ...                    ...
# 28561                    1
# 19588                    0
# 15900                    0
# 7133                     0
# 7317                     1
#
# [9769 rows x 1 columns]

# %%
pipeline_dt=Pipeline([('classifier',DecisionTreeClassifier(criterion='entropy'))])

# %%
pipeline_randomforest=Pipeline([('classifier',RandomForestClassifier(criterion='entropy'))])

# %%
pipelines = [pipeline_dt, pipeline_randomforest]

# %%
pipelines[0]
# Out:
# Pipeline(steps=[('classifier', DecisionTreeClassifier(criterion='entropy'))])

# %%
best_accuracy=0.0

# %%
best_classifier=0

# %%
best_pipeline = ''

# %%
pipe_dict = {
    0: 'Decision Tree',
    1: 'RandomForest'
}

# %%
for pipe in pipelines:
    pipe.fit(X_train, y_train)
# Out:
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)

# %%
for i,model in enumerate(pipelines):
    print("{} Test Accuracy: {}".format(pipe_dict[i],model.score(X_test,y_test)))
# Out:
# Decision Tree Test Accuracy: 0.8131845634148838
# RandomForest Test Accuracy: 0.8563824342307299

# %%
for i,model in enumerate(pipelines):
    if(model.score(X_test,y_test)<best_accuracy):
        best_accuracy = model.score(X_test,y_test)
        best_pipeline = model
        best_classifier=i
print("Classifier with best accuracy: {}".format(pipe_dict[best_classifier]))
# Out:
# Classifier with best accuracy: Decision Tree

# %%
from sklearn.model_selection import GridSearchCV

# %%
arr_params = []
for num in range(1,30):
    arr_params.append(num)

# %%
search_space = [{'classifier': [RandomForestClassifier(criterion='entropy')],
                 'classifier__n_estimators': [10, 100, 1000],
                 'classifier__min_samples_split': [2, 3]},
               {'classifier': [DecisionTreeClassifier(criterion='entropy')],
                 'classifier__alpha': [0, 1, 2],
                 'classifier__min_samples_split': [2, 3]}]

# %%
clf = GridSearchCV(pipeline_randomforest, search_space)

# %%
clf
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('classifier',
#                                         RandomForestClassifier(criterion='entropy'))]),
#              param_grid=[{'classifier': [RandomForestClassifier(criterion='entropy')],
#                           'classifier__min_samples_split': [2, 3],
#                           'classifier__n_estimators': [10, 100, 1000]},
#                          {'classifier': [DecisionTreeClassifier(criterion='entropy')],
#                           'classifier__alpha': [0, 1, 2],
#                           'classifier__min_samples_split': [2, 3]}])

# %%
best_model = clf.fit(X_train, y_train)
# Out:
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/vanshgadhia/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/dn/bs507yz577q45m4_yg_b4xhw0000gn/T/ipykernel_34068/124875731.py in <module>
# ----> 1 best_model = clf.fit(X_train, y_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1294     def _run_search(self, evaluate_candidates):
#    1295         """Search all candidates in param_grid"""
# -> 1296         evaluate_candidates(ParameterGrid(self.param_grid))
#    1297
#    1298
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     584             cloned_parameters[k] = clone(v, safe=False)
#     585
# --> 586         estimator = estimator.set_params(**cloned_parameters)
#     587
#     588     start_time = time.time()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py in set_params(self, **kwargs)
#     148         self
#     149         """
# --> 150         self._set_params('steps', **kwargs)
#     151         return self
#     152
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/metaestimators.py in _set_params(self, attr, **params)
#      52                 self._replace_estimator(attr, name, params.pop(name))
#      53         # 3. Step parameters and other initialisation arguments
# ---> 54         super().set_params(**params)
#      55         return self
#      56
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in set_params(self, **params)
#     240
#     241         for key, sub_params in nested_params.items():
# --> 242             valid_params[key].set_params(**sub_params)
#     243
#     244         return self
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in set_params(self, **params)
#     228             key, delim, sub_key = key.partition('__')
#     229             if key not in valid_params:
# --> 230                 raise ValueError('Invalid parameter %s for estimator %s. '
#     231                                  'Check the list of available parameters '
#     232                                  'with `estimator.get_params().keys()`.' %
#
# ValueError: Invalid parameter alpha for estimator DecisionTreeClassifier(criterion='entropy'). Check the list of available parameters with `estimator.get_params().keys()`.

# %%
best_model.best_estimator_.get_params()['classifier']

# %%
best_model.score(X_test,y_test)

# %%
df_grid = pd.DataFrame(data=clf.cv_results_)

# %%
df_grid
